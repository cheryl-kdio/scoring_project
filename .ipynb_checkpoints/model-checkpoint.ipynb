# %%
execfile("init.py")
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math
from scipy import stats
import numpy as np

import importlib
import functions
# Out:
# ================================Start================================
# Loading database
#
# Transforming type of target column
#
# Decoding bytes to utf-8
#
# Transforming type of date column
#
# Split df to test and training samples
#
# Identifying categorical and quantitative variables
#
# ================================End================================

# %%
cont_var = []
#['NBJ_ARR_mm1', 'IMPAYE_12dm', 'DEPASSEMENT', 'NBJDEPDP_mm3','DEPASSEMENT_6dm']
cat_var = ['INDRSKITDBDF','Degra_IRPRO_continue_3dm','Degra_IRPRO_mm1','Degra_couleur_IRPRO_mm1','classe_finale_NDB']

X = X_train[cont_var+cat_var]
y = X_train['cible_1']

# %%
import statsmodels.api as sm 
#reference = variable with high risk rate
modalites_reference = []

for var in cat_var :
    freq_evt = (X_train.groupby([var],as_index=True)[cible].mean()).reset_index().sort_values(by=[cible],ascending=True).reset_index(drop=True)
    modalites_reference.append(var+"_"+str(freq_evt[var][0]))    

new_X = pd.get_dummies(X,columns=cat_var).drop(modalites_reference,axis=1).copy()

# %%
new_X
# Out:
#         INDRSKITDBDF_0  INDRSKITDBDF_1  Degra_IRPRO_continue_3dm_1  \
# 527714            True           False                       False
# 324008            True           False                       False
# 464966            True           False                        True
# 136481            True           False                       False
# 113310            True           False                       False
# ...                ...             ...                         ...
# 370799            True           False                       False
# 3560              True           False                       False
# 451641            True           False                       False
# 241106            True           False                       False
# 145189            True           False                       False
#
#         Degra_IRPRO_mm1_ .  Degra_IRPRO_mm1_ 0  Degra_IRPRO_mm1_ 1  \
# 527714               False                True               False
# 324008               False                True               False
# 464966               False               False               False
# 136481               False               False               False
# 113310               False                True               False
# ...                    ...                 ...                 ...
# 370799               False               False               False
# 3560                 False                True               False
# 451641               False                True               False
# 241106               False                True               False
# 145189               False                True               False
#
#         Degra_IRPRO_mm1_ 2  Degra_IRPRO_mm1_ 3  Degra_IRPRO_mm1_ 4  \
# 527714               False               False               False
# 324008               False               False               False
# 464966               False               False               False
# 136481               False               False               False
# 113310               False               False               False
# ...                    ...                 ...                 ...
# 370799               False               False               False
# 3560                 False               False               False
# 451641               False               False               False
# 241106               False               False               False
# 145189               False               False               False
#
#         Degra_IRPRO_mm1_ 5  ...  classe_finale_NDB_ 8  classe_finale_NDB_ 9  \
# 527714               False  ...                 False                 False
# 324008               False  ...                 False                 False
# 464966               False  ...                 False                 False
# 136481               False  ...                 False                 False
# 113310               False  ...                 False                 False
# ...                    ...  ...                   ...                   ...
# 370799               False  ...                 False                 False
# 3560                 False  ...                 False                 False
# 451641               False  ...                 False                 False
# 241106               False  ...                 False                 False
# 145189               False  ...                 False                 False
#
#         classe_finale_NDB_10  classe_finale_NDB_12  classe_finale_NDB_13  \
# 527714                 False                 False                 False
# 324008                 False                 False                 False
# 464966                 False                 False                 False
# 136481                 False                 False                 False
# 113310                 False                 False                 False
# ...                      ...                   ...                   ...
# 370799                 False                 False                 False
# 3560                   False                 False                 False
# 451641                 False                 False                 False
# 241106                 False                 False                 False
# 145189                 False                 False                 False
#
#         classe_finale_NDB_14  classe_finale_NDB_15  classe_finale_NDB_16  \
# 527714                 False                 False                 False
# 324008                 False                 False                 False
# 464966                 False                 False                 False
# 136481                 False                 False                 False
# 113310                 False                 False                 False
# ...                      ...                   ...                   ...
# 370799                 False                 False                 False
# 3560                   False                 False                 False
# 451641                 False                 False                 False
# 241106                 False                 False                 False
# 145189                 False                 False                 False
#
#         classe_finale_NDB_17  classe_finale_NDB_18
# 527714                 False                 False
# 324008                 False                 False
# 464966                 False                 False
# 136481                 False                 False
# 113310                 False                 False
# ...                      ...                   ...
# 370799                 False                 False
# 3560                   False                 False
# 451641                 False                 False
# 241106                 False                 False
# 145189                 False                 False
#
# [417238 rows x 38 columns]

# %%
# Compute VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = new_X.columns

# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(new_X.values, i) for i in range(len(new_X.columns))] 

print(vif_data)
# Out:
#                        feature       VIF
# 0               INDRSKITDBDF_0  0.021789
# 1               INDRSKITDBDF_1  0.022077
# 2   Degra_IRPRO_continue_3dm_1  0.000101
# 3           Degra_IRPRO_mm1_ .  0.021994
# 4           Degra_IRPRO_mm1_ 0  0.021804
# 5           Degra_IRPRO_mm1_ 1  0.021834
# 6           Degra_IRPRO_mm1_ 2  0.021898
# 7           Degra_IRPRO_mm1_ 3  0.022103
# 8           Degra_IRPRO_mm1_ 4  0.024356
# 9           Degra_IRPRO_mm1_ 5  0.035970
# 10          Degra_IRPRO_mm1_-1  0.021842
# 11          Degra_IRPRO_mm1_-2  0.021894
# 12          Degra_IRPRO_mm1_-3  0.022030
# 13          Degra_IRPRO_mm1_-4  0.022404
# 14          Degra_IRPRO_mm1_-5  0.023594
# 15          Degra_IRPRO_mm1_-6  0.030842
# 16          Degra_IRPRO_mm1_-7  0.165212
# 17  Degra_couleur_IRPRO_mm1_ 1  0.000094
# 18  Degra_couleur_IRPRO_mm1_ 2  0.002210
# 19  Degra_couleur_IRPRO_mm1_ 3  0.045718
# 20  Degra_couleur_IRPRO_mm1_-1  0.000078
# 21  Degra_couleur_IRPRO_mm1_-2  0.000595
# 22        classe_finale_NDB_ 2  0.000043
# 23        classe_finale_NDB_ 3  0.000045
# 24        classe_finale_NDB_ 4  0.000052
# 25        classe_finale_NDB_ 5  0.000062
# 26        classe_finale_NDB_ 6  0.000079
# 27        classe_finale_NDB_ 7  0.000095
# 28        classe_finale_NDB_ 8  0.000076
# 29        classe_finale_NDB_ 9  0.000078
# 30        classe_finale_NDB_10  0.000088
# 31        classe_finale_NDB_12  0.000084
# 32        classe_finale_NDB_13  0.000095
# 33        classe_finale_NDB_14  0.000120
# 34        classe_finale_NDB_15  0.000090
# 35        classe_finale_NDB_16  0.000294
# 36        classe_finale_NDB_17  0.000213
# 37        classe_finale_NDB_18  0.001740

# %%
print(new_X.columns)
# Out:
# Index(['DEPASSEMENT', 'INDRSKITDBDF_0', 'INDRSKITDBDF_1',
#        'Degra_IRPRO_continue_3dm_1', 'Degra_IRPRO_mm1_ .',
#        'Degra_IRPRO_mm1_ 0', 'Degra_IRPRO_mm1_ 1', 'Degra_IRPRO_mm1_ 2',
#        'Degra_IRPRO_mm1_ 3', 'Degra_IRPRO_mm1_ 4', 'Degra_IRPRO_mm1_ 5',
#        'Degra_IRPRO_mm1_-1', 'Degra_IRPRO_mm1_-2', 'Degra_IRPRO_mm1_-3',
#        'Degra_IRPRO_mm1_-4', 'Degra_IRPRO_mm1_-5', 'Degra_IRPRO_mm1_-6',
#        'Degra_IRPRO_mm1_-7', 'Degra_couleur_IRPRO_mm1_ 1',
#        'Degra_couleur_IRPRO_mm1_ 2', 'Degra_couleur_IRPRO_mm1_ 3',
#        'Degra_couleur_IRPRO_mm1_-1', 'Degra_couleur_IRPRO_mm1_-2',
#        'classe_finale_NDB_ 2', 'classe_finale_NDB_ 3', 'classe_finale_NDB_ 4',
#        'classe_finale_NDB_ 5', 'classe_finale_NDB_ 6', 'classe_finale_NDB_ 7',
#        'classe_finale_NDB_ 8', 'classe_finale_NDB_ 9', 'classe_finale_NDB_10',
#        'classe_finale_NDB_12', 'classe_finale_NDB_13', 'classe_finale_NDB_14',
#        'classe_finale_NDB_15', 'classe_finale_NDB_16', 'classe_finale_NDB_17',
#        'classe_finale_NDB_18'],
#       dtype='object')

# %%
print(new_X[cont_var].isna().sum())
# Out:
# NBJ_ARR_mm1        2325
# IMPAYE_12dm        2266
# DEPASSEMENT           0
# NBJDEPDP_mm3       8225
# DEPASSEMENT_6dm    2266
# dtype: int64

# %%
variance_inflation_factor(new_X[cont_var[1]],0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 variance_inflation_factor(new_X[cont_var[1]],0)
#
# File /opt/conda/lib/python3.12/site-packages/statsmodels/stats/outliers_influence.py:191, in variance_inflation_factor(exog, exog_idx)
#     152 def variance_inflation_factor(exog, exog_idx):
#     153     """
#     154     Variance inflation factor, VIF, for one exogenous variable
#     155
#    (...)
#     189     https://en.wikipedia.org/wiki/Variance_inflation_factor
#     190     """
# --> 191     k_vars = exog.shape[1]
#     192     exog = np.asarray(exog)
#     193     x_i = exog[:, exog_idx]
#
# IndexError: tuple index out of range

# %%
new_X[cont_var].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417238 entries, 527714 to 145189
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   NBJ_ARR_mm1      414913 non-null  float64
#  1   IMPAYE_12dm      414972 non-null  float64
#  2   DEPASSEMENT      417238 non-null  float64
#  3   NBJDEPDP_mm3     409013 non-null  float64
#  4   DEPASSEMENT_6dm  414972 non-null  float64
# dtypes: float64(5)
# memory usage: 19.1 MB

# %%
X.shape[1]
# Out:
# 10
